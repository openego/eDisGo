# %%
import pandas as pd
from pathlib import Path
from edisgo import flex_opt
from edisgo import network
from edisgo import tools
from edisgo import EDisGo


grid_name = 'ding0_test_network'


curr_path = Path.cwd()
parent_dir = curr_path.parents[3]
# simbench_grids_dir = parent_dir / 'simbench'
grid_dir = parent_dir / grid_name
print (grid_dir)
# Out:
# /usr/local/anaconda3/envs/edisgo/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py:338: SAWarning: Ignoring declarative-like tuple value of attribute segment: possibly a copy-and-paste error with a comma left at the end of the line?
#   "left at the end of the line?" % k)
# /usr/local/anaconda3/envs/edisgo/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py:338: SAWarning: Ignoring declarative-like tuple value of attribute cable: possibly a copy-and-paste error with a comma left at the end of the line?
#   "left at the end of the line?" % k)
# /Users/heikernleong/Documents/localFiles/sa_code/edisgo/hk_edisgo/ding0_test_network

# %%
# worst_case_analysis = 'worst-case-feedin'
worst_case_analysis = 'worst-case'
edisgo = EDisGo(ding0_grid=grid_dir, worst_case_analysis=worst_case_analysis)
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version 0.17.1.
# Please read the release notes at https://pypsa.org/doc/release_notes.html
# carefully to prepare your network for import.
#
# INFO:pypsa.io:Imported network ding0_test_network has buses, generators, lines, loads, transformers

# %%
for key in edisgo.timeseries.__dict__:
    print (key)
#     display(edisgo.timeseries.__dict__[key])
    
# print('slack' in edisgo.timeseries._generators_active_power.columns)
# print(edisgo.timeseries._generators_active_power.columns)
display (edisgo.timeseries._timeindex)
display (edisgo.timeseries._generators_active_power.head())
cols = edisgo.timeseries._generators_active_power.columns
# print(cols)
'slack' in cols
display (edisgo.timeseries._storage_units_reactive_power)
# edisgo.analyze()
# Out:
# _timeindex
# _generators_active_power
# _generators_reactive_power
# _loads_active_power
# _loads_reactive_power
# _storage_units_active_power
# _storage_units_reactive_power
# _charging_points_active_power
# _charging_points_reactive_power
# _curtailment
# mode
# DatetimeIndex(['1970-01-01 00:00:00', '1970-01-01 01:00:00'], dtype='datetime64[ns]', freq='H')
# name                 Generator_mvgd_2761_lvgd_203884_solar_roof_mounted_1593663  \
# 1970-01-01 00:00:00                                            0.00765
# 1970-01-01 01:00:00                                            0.00000
#
# name                 Generator_mvgd_2761_lvgd_203886_solar_roof_mounted_1564359  \
# 1970-01-01 00:00:00                                           0.005202
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_203893_solar_roof_mounted_1604374  \
# 1970-01-01 00:00:00                                             0.0034
# 1970-01-01 01:00:00                                             0.0000
#
# name                 Generator_mvgd_2761_lvgd_203897_solar_roof_mounted_1567265  \
# 1970-01-01 00:00:00                                             0.0017
# 1970-01-01 01:00:00                                             0.0000
#
# name                 Generator_mvgd_2761_lvgd_203898_solar_roof_mounted_1572933  \
# 1970-01-01 00:00:00                                           0.005304
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_203899_solar_roof_mounted_1582357  \
# 1970-01-01 00:00:00                                            0.00272
# 1970-01-01 01:00:00                                            0.00000
#
# name                 Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1595311  \
# 1970-01-01 00:00:00                                           0.004335
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1596285  \
# 1970-01-01 00:00:00                                           0.002652
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_203904_solar_roof_mounted_1595545  \
# 1970-01-01 00:00:00                                           0.004054
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_203905_solar_roof_mounted_1590517  \
# 1970-01-01 00:00:00                                           0.004819
# 1970-01-01 01:00:00                                           0.000000
#
# name                 ...  Generator_mvgd_2761_wind_onshore_1475356  \
# 1970-01-01 00:00:00  ...                                       1.5
# 1970-01-01 01:00:00  ...                                       0.0
#
# name                 Generator_mvgd_2761_wind_onshore_1475357  \
# 1970-01-01 00:00:00                                       1.5
# 1970-01-01 01:00:00                                       0.0
#
# name                 Generator_mvgd_2761_wind_onshore_1475358  \
# 1970-01-01 00:00:00                                       1.5
# 1970-01-01 01:00:00                                       0.0
#
# name                 Generator_mvgd_2761_wind_onshore_1475359  \
# 1970-01-01 00:00:00                                       1.5
# 1970-01-01 01:00:00                                       0.0
#
# name                 Generator_mvgd_2761_wind_onshore_1475363  \
# 1970-01-01 00:00:00                                       1.8
# 1970-01-01 01:00:00                                       0.0
#
# name                 Generator_mvgd_2761_wind_onshore_1475364  \
# 1970-01-01 00:00:00                                       1.8
# 1970-01-01 01:00:00                                       0.0
#
# name                 Generator_mvgd_2761_lvgd_196761_solar_roof_mounted_1596615  \
# 1970-01-01 00:00:00                                            0.00102
# 1970-01-01 01:00:00                                            0.00000
#
# name                 Generator_mvgd_2761_lvgd_449723_solar_roof_mounted_1588362  \
# 1970-01-01 00:00:00                                             0.0085
# 1970-01-01 01:00:00                                             0.0000
#
# name                 Generator_mvgd_2761_lvgd_198602_solar_roof_mounted_1588638  \
# 1970-01-01 00:00:00                                           0.008398
# 1970-01-01 01:00:00                                           0.000000
#
# name                 Generator_mvgd_2761_lvgd_198684_solar_roof_mounted_1591905
# 1970-01-01 00:00:00                                           0.002295
# 1970-01-01 01:00:00                                           0.000000
#
# [2 rows x 31 columns]
# Empty DataFrame
# Columns: []
# Index: [1970-01-01 00:00:00, 1970-01-01 01:00:00]
