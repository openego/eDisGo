# %%
import pandas as pd
from pathlib import Path
from edisgo import flex_opt
from edisgo import network
from edisgo import tools
from edisgo import EDisGo


grid_name = 'ding0_test_network'


curr_path = Path.cwd()
parent_dir = curr_path.parents[3]
# simbench_grids_dir = parent_dir / 'simbench'
grid_dir = parent_dir / grid_name
print (grid_dir)
# Out:
# /usr/local/anaconda3/envs/edisgo/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py:338: SAWarning: Ignoring declarative-like tuple value of attribute segment: possibly a copy-and-paste error with a comma left at the end of the line?
#   "left at the end of the line?" % k)
# /usr/local/anaconda3/envs/edisgo/lib/python3.6/site-packages/sqlalchemy/ext/declarative/base.py:338: SAWarning: Ignoring declarative-like tuple value of attribute cable: possibly a copy-and-paste error with a comma left at the end of the line?
#   "left at the end of the line?" % k)
# /Users/heikernleong/Documents/localFiles/sa_code/edisgo/hk_edisgo/ding0_test_network

# %%
worst_case_analysis = 'worst-case-feedin'
edisgo = EDisGo(ding0_grid=grid_dir, worst_case_analysis=worst_case_analysis)
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version 0.17.1.
# Please read the release notes at https://pypsa.org/doc/release_notes.html
# carefully to prepare your network for import.
#
# INFO:pypsa.io:Imported network ding0_test_network has buses, generators, lines, loads, transformers

# %%
for key in edisgo.timeseries.__dict__:
    print (key)
    display(edisgo.timeseries.__dict__[key])
# Out:
# {'_timeindex': DatetimeIndex(['1970-01-01'], dtype='datetime64[ns]', freq='H'), '_generators_active_power': name        Generator_mvgd_2761_lvgd_203884_solar_roof_mounted_1593663  \
# 1970-01-01                                            0.00765
#
# name        Generator_mvgd_2761_lvgd_203886_solar_roof_mounted_1564359  \
# 1970-01-01                                           0.005202
#
# name        Generator_mvgd_2761_lvgd_203893_solar_roof_mounted_1604374  \
# 1970-01-01                                             0.0034
#
# name        Generator_mvgd_2761_lvgd_203897_solar_roof_mounted_1567265  \
# 1970-01-01                                             0.0017
#
# name        Generator_mvgd_2761_lvgd_203898_solar_roof_mounted_1572933  \
# 1970-01-01                                           0.005304
#
# name        Generator_mvgd_2761_lvgd_203899_solar_roof_mounted_1582357  \
# 1970-01-01                                            0.00272
#
# name        Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1595311  \
# 1970-01-01                                           0.004335
#
# name        Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1596285  \
# 1970-01-01                                           0.002652
#
# name        Generator_mvgd_2761_lvgd_203904_solar_roof_mounted_1595545  \
# 1970-01-01                                           0.004054
#
# name        Generator_mvgd_2761_lvgd_203905_solar_roof_mounted_1590517  ...  \
# 1970-01-01                                           0.004819           ...
#
# name        Generator_mvgd_2761_wind_onshore_1475356  \
# 1970-01-01                                       1.5
#
# name        Generator_mvgd_2761_wind_onshore_1475357  \
# 1970-01-01                                       1.5
#
# name        Generator_mvgd_2761_wind_onshore_1475358  \
# 1970-01-01                                       1.5
#
# name        Generator_mvgd_2761_wind_onshore_1475359  \
# 1970-01-01                                       1.5
#
# name        Generator_mvgd_2761_wind_onshore_1475363  \
# 1970-01-01                                       1.8
#
# name        Generator_mvgd_2761_wind_onshore_1475364  \
# 1970-01-01                                       1.8
#
# name        Generator_mvgd_2761_lvgd_196761_solar_roof_mounted_1596615  \
# 1970-01-01                                            0.00102
#
# name        Generator_mvgd_2761_lvgd_449723_solar_roof_mounted_1588362  \
# 1970-01-01                                             0.0085
#
# name        Generator_mvgd_2761_lvgd_198602_solar_roof_mounted_1588638  \
# 1970-01-01                                           0.008398
#
# name        Generator_mvgd_2761_lvgd_198684_solar_roof_mounted_1591905
# 1970-01-01                                           0.002295
#
# [1 rows x 31 columns], '_generators_reactive_power': name        Generator_mvgd_2761_lvgd_203884_solar_roof_mounted_1593663  \
# 1970-01-01                                          -0.003705
#
# name        Generator_mvgd_2761_lvgd_203886_solar_roof_mounted_1564359  \
# 1970-01-01                                          -0.002519
#
# name        Generator_mvgd_2761_lvgd_203893_solar_roof_mounted_1604374  \
# 1970-01-01                                          -0.001647
#
# name        Generator_mvgd_2761_lvgd_203897_solar_roof_mounted_1567265  \
# 1970-01-01                                          -0.000823
#
# name        Generator_mvgd_2761_lvgd_203898_solar_roof_mounted_1572933  \
# 1970-01-01                                          -0.002569
#
# name        Generator_mvgd_2761_lvgd_203899_solar_roof_mounted_1582357  \
# 1970-01-01                                          -0.001317
#
# name        Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1595311  \
# 1970-01-01                                            -0.0021
#
# name        Generator_mvgd_2761_lvgd_203900_solar_roof_mounted_1596285  \
# 1970-01-01                                          -0.001284
#
# name        Generator_mvgd_2761_lvgd_203904_solar_roof_mounted_1595545  \
# 1970-01-01                                          -0.001964
#
# name        Generator_mvgd_2761_lvgd_203905_solar_roof_mounted_1590517  ...  \
# 1970-01-01                                          -0.002334           ...
#
# name        Generator_mvgd_2761_wind_onshore_1475356  \
# 1970-01-01                                 -0.726483
#
# name        Generator_mvgd_2761_wind_onshore_1475357  \
# 1970-01-01                                 -0.726483
#
# name        Generator_mvgd_2761_wind_onshore_1475358  \
# 1970-01-01                                 -0.726483
#
# name        Generator_mvgd_2761_wind_onshore_1475359  \
# 1970-01-01                                 -0.726483
#
# name        Generator_mvgd_2761_wind_onshore_1475363  \
# 1970-01-01                                  -0.87178
#
# name        Generator_mvgd_2761_wind_onshore_1475364  \
# 1970-01-01                                  -0.87178
#
# name        Generator_mvgd_2761_lvgd_196761_solar_roof_mounted_1596615  \
# 1970-01-01                                          -0.000335
#
# name        Generator_mvgd_2761_lvgd_449723_solar_roof_mounted_1588362  \
# 1970-01-01                                          -0.002794
#
# name        Generator_mvgd_2761_lvgd_198602_solar_roof_mounted_1588638  \
# 1970-01-01                                           -0.00276
#
# name        Generator_mvgd_2761_lvgd_198684_solar_roof_mounted_1591905
# 1970-01-01                                          -0.000754
#
# [1 rows x 31 columns], '_loads_active_power': name        Load_mvgd_2761_lac_119675_industrial  \
# 1970-01-01                              0.202017
#
# name        Load_mvgd_2761_lac_119675_residential  \
# 1970-01-01                               0.481421
#
# name        Load_mvgd_2761_lac_119675_retail  Load_mvgd_2761_lvgd_196758_1  \
# 1970-01-01                          0.101722                      0.000102
#
# name        Load_mvgd_2761_lvgd_196758_2  Load_mvgd_2761_lvgd_196758_3  \
# 1970-01-01                      0.000102                      0.000102
#
# name        Load_mvgd_2761_lvgd_196758_4  Load_mvgd_2761_lvgd_196758_5  \
# 1970-01-01                      0.000102                      0.000102
#
# name        Load_mvgd_2761_lvgd_196758_6  Load_mvgd_2761_lvgd_196758_7  ...  \
# 1970-01-01                      0.000102                      0.000102  ...
#
# name        Load_mvgd_2761_lvgd_198685_69  Load_mvgd_2761_lvgd_198685_70  \
# 1970-01-01                       0.000102                       0.000102
#
# name        Load_mvgd_2761_lvgd_198685_71  Load_mvgd_2761_lvgd_198685_72  \
# 1970-01-01                       0.000102                       0.000102
#
# name        Load_mvgd_2761_lvgd_198685_73  Load_mvgd_2761_lvgd_198685_74  \
# 1970-01-01                       0.000102                       0.000102
#
# name        Load_mvgd_2761_lvgd_198685_75  Load_mvgd_2761_lvgd_198685_76  \
# 1970-01-01                       0.000102                       0.000102
#
# name        Load_mvgd_2761_lvgd_198685_77  Load_mvgd_2761_lvgd_449894_1
# 1970-01-01                       0.000102                      0.000147
#
# [1 rows x 550 columns], '_loads_reactive_power': name        Load_mvgd_2761_lac_119675_industrial  \
# 1970-01-01                              0.097841
#
# name        Load_mvgd_2761_lac_119675_residential  \
# 1970-01-01                               0.233163
#
# name        Load_mvgd_2761_lac_119675_retail  Load_mvgd_2761_lvgd_196758_1  \
# 1970-01-01                          0.049266                      0.000033
#
# name        Load_mvgd_2761_lvgd_196758_2  Load_mvgd_2761_lvgd_196758_3  \
# 1970-01-01                      0.000033                      0.000033
#
# name        Load_mvgd_2761_lvgd_196758_4  Load_mvgd_2761_lvgd_196758_5  \
# 1970-01-01                      0.000033                      0.000033
#
# name        Load_mvgd_2761_lvgd_196758_6  Load_mvgd_2761_lvgd_196758_7  ...  \
# 1970-01-01                      0.000033                      0.000033  ...
#
# name        Load_mvgd_2761_lvgd_198685_69  Load_mvgd_2761_lvgd_198685_70  \
# 1970-01-01                       0.000033                       0.000033
#
# name        Load_mvgd_2761_lvgd_198685_71  Load_mvgd_2761_lvgd_198685_72  \
# 1970-01-01                       0.000033                       0.000033
#
# name        Load_mvgd_2761_lvgd_198685_73  Load_mvgd_2761_lvgd_198685_74  \
# 1970-01-01                       0.000033                       0.000033
#
# name        Load_mvgd_2761_lvgd_198685_75  Load_mvgd_2761_lvgd_198685_76  \
# 1970-01-01                       0.000033                       0.000033
#
# name        Load_mvgd_2761_lvgd_198685_77  Load_mvgd_2761_lvgd_449894_1
# 1970-01-01                       0.000033                      0.000048
#
# [1 rows x 550 columns], '_storage_units_active_power': Empty DataFrame
# Columns: []
# Index: [1970-01-01 00:00:00], '_storage_units_reactive_power': Empty DataFrame
# Columns: []
# Index: [1970-01-01 00:00:00], '_charging_points_active_power': Empty DataFrame
# Columns: []
# Index: [], '_charging_points_reactive_power': Empty DataFrame
# Columns: []
# Index: [], '_curtailment': Empty DataFrame
# Columns: []
# Index: [], 'mode': 'worst-case-feedin'}
